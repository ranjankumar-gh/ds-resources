# %% [markdown]
# # Multiple Regression (gradient descent)

# %% [markdown]
# In the first notebook we explored multiple regression using graphlab create. Now we will use graphlab along with numpy to solve for the regression weights with gradient descent.
#
# In this notebook we will cover estimating multiple regression weights via gradient descent. You will:
# * Add a constant column of 1's to a graphlab SFrame to account for the intercept
# * Convert an SFrame into a Numpy array
# * Write a predict_output() function using Numpy
# * Write a numpy function to compute the derivative of the regression weights with respect to a single feature
# * Write gradient descent function to compute the regression weights given an initial weight vector, step size and tolerance.
# * Use the gradient descent function to estimate regression weights for multiple features

# %% [markdown]
# # Fire up graphlab create

# %% [markdown]
# Make sure you have the latest version of graphlab (>= 1.7)

# %%
import graphlab
# Out:
# A newer version of GraphLab Create (v1.8) is available! Your current version is v1.7.1.
#
# You can use pip to upgrade the graphlab-create package. For more information see https://dato.com/products/create/upgrade.

# %% [markdown]
# # Load in house sales data
#
# Dataset is from house sales in King County, the region where the city of Seattle, WA is located.

# %%
sales = graphlab.SFrame('kc_house_data.gl/')
# Out:
# [INFO] 1453096632 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_FILE to C:\Users\ranjank\AppData\Local\Dato\Dato Launcher\lib\site-packages\certifi\cacert.pem
# 1453096632 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_DIR to
# This non-commercial license of GraphLab Create is assigned to ranjank@cdac.in and will expire on November 23, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-19848 - Server binary: C:\Users\ranjank\AppData\Local\Dato\Dato Launcher\lib\site-packages\graphlab\unity_server.exe - Server log: C:\Users\ranjank\AppData\Local\Temp\graphlab_server_1453096632.log.0
# [INFO] GraphLab Server Version: 1.7.1

# %% [markdown]
# If we want to do any "feature engineering" like creating new features or adjusting existing ones we should do this directly using the SFrames as seen in the other Week 2 notebook. For this notebook, however, we will work with the existing features.

# %% [markdown]
# # Convert to Numpy Array

# %% [markdown]
# Although SFrames offer a number of benefits to users (especially when using Big Data and built-in graphlab functions) in order to understand the details of the implementation of algorithms it's important to work with a library that allows for direct (and optimized) matrix operations. Numpy is a Python solution to work with matrices (or any multi-dimensional "array").
#
# Recall that the predicted value given the weights and the features is just the dot product between the feature and weight vector. Similarly, if we put all of the features row-by-row in a matrix then the predicted value for *all* the observations can be computed by right multiplying the "feature matrix" by the "weight vector".
#
# First we need to take the SFrame of our data and convert it into a 2D numpy array (also called a matrix). To do this we use graphlab's built in .to_dataframe() which converts the SFrame into a Pandas (another python library) dataframe. We can then use Panda's .as_matrix() to convert the dataframe into a numpy matrix.

# %%
import numpy as np # note this allows us to refer to numpy as np instead

# %% [markdown]
# Now we will write a function that will accept an SFrame, a list of feature names (e.g. ['sqft_living', 'bedrooms']) and an target feature e.g. ('price') and will return two things:
# * A numpy matrix whose columns are the desired features plus a constant column (this is how we create an 'intercept')
# * A numpy array containing the values of the output
#
# With this in mind, complete the following function (where there's an empty line you should write a line of code that does what the comment above indicates)
#
# **Please note you will need GraphLab Create version at least 1.7.1 in order for .to_numpy() to work!**

# %%
def get_numpy_data(data_sframe, features, output):
    data_sframe['constant'] = 1 # this is how you add a constant column to an SFrame
    # add the column 'constant' to the front of the features list so that we can extract it along with the others:
    features = ['constant'] + features # this is how you combine two lists
   
    # select the columns of data_SFrame given by the features list into the SFrame features_sframe (now including constant):
    features_sframe = data_sframe[features]
       
    # the following line will convert the features_SFrame into a numpy matrix:
    feature_matrix = features_sframe.to_numpy()
       
    # assign the column of data_sframe associated with the output to the SArray output_sarray
    output_sarray = data_sframe[output]
    
    # the following will convert the SArray into a numpy array by first converting it to a list
    output_array = output_sarray.to_numpy()
    
    return(feature_matrix, output_array)

# %% [markdown]
# For testing let's use the 'sqft_living' feature and a constant as our features and price as our output:

# %%
(example_features, example_output) = get_numpy_data(sales, ['sqft_living'], 'price') # the [] around 'sqft_living' makes it a list
print example_features[0,:] # this accesses the first row of the data the ':' indicates 'all columns'
print example_output[0] # and the corresponding output
# Out:
# [  1.00000000e+00   1.18000000e+03]
# 221900.0

# %% [markdown]
# # Predicting output given regression weights

# %% [markdown]
# Suppose we had the weights [1.0, 1.0] and the features [1.0, 1180.0] and we wanted to compute the predicted output 1.0\*1.0 + 1.0\*1180.0 = 1181.0 this is the dot product between these two arrays. If they're numpy arrayws we can use np.dot() to compute this:

# %%
my_weights = np.array([1., 1.]) # the example weights
my_features = example_features[0,] # we'll use the first data point
predicted_value = np.dot(my_features, my_weights)
print predicted_value
# Out:
# 1181.0

# %% [markdown]
# np.dot() also works when dealing with a matrix and a vector. Recall that the predictions from all the observations is just the RIGHT (as in weights on the right) dot product between the features *matrix* and the weights *vector*. With this in mind finish the following predict_output function to compute the predictions for an entire matrix of features given the matrix and the weights:

# %%
def predict_output(feature_matrix, weights):
    # assume feature_matrix is a numpy matrix containing the features as columns and weights is a corresponding numpy array
    # create the predictions vector by using np.dot()
    predictions = np.dot(feature_matrix, weights)

    return(predictions)

# %% [markdown]
# If you want to test your code run the following cell:

# %%
test_predictions = predict_output(example_features, my_weights)
print test_predictions[0] # should be 1181.0
print test_predictions[1] # should be 2571.0
# Out:
# 1181.0
# 2571.0

# %% [markdown]
# # Computing the Derivative

# %% [markdown]
# We are now going to move to computing the derivative of the regression cost function. Recall that the cost function is the sum over the data points of the squared difference between an observed output and a predicted output.
#
# Since the derivative of a sum is the sum of the derivatives we can compute the derivative for a single data point and then sum over data points. We can write the squared difference between the observed output and predicted output for a single point as follows:
#
# (w[0]\*[CONSTANT] + w[1]\*[feature_1] + ... + w[i] \*[feature_i] + ... +  w[k]\*[feature_k] - output)^2
#
# Where we have k features and a constant. So the derivative with respect to weight w[i] by the chain rule is:
#
# 2\*(w[0]\*[CONSTANT] + w[1]\*[feature_1] + ... + w[i] \*[feature_i] + ... +  w[k]\*[feature_k] - output)\* [feature_i]
#
# The term inside the paranethesis is just the error (difference between prediction and output). So we can re-write this as:
#
# 2\*error\*[feature_i]
#
# That is, the derivative for the weight for feature i is the sum (over data points) of 2 times the product of the error and the feature itself. In the case of the constant then this is just twice the sum of the errors!
#
# Recall that twice the sum of the product of two vectors is just twice the dot product of the two vectors. Therefore the derivative for the weight for feature_i is just two times the dot product between the values of feature_i and the current errors.
#
# With this in mind complete the following derivative function which computes the derivative of the weight given the value of the feature (over all data points) and the errors (over all data points).

# %%
def feature_derivative(errors, feature):
    # Assume that errors and feature are both numpy arrays of the same length (number of data points)
    # compute twice the dot product of these vectors as 'derivative' and return the value
    #print errors
    #print feature
    derivative = 2*np.dot(errors,feature)
    
    return(derivative)
    #return

# %% [markdown]
# To test your feature derivartive run the following:

# %%
(example_features, example_output) = get_numpy_data(sales, ['sqft_living'], 'price') 
my_weights = np.array([0., 0.]) # this makes all the predictions 0
test_predictions = predict_output(example_features, my_weights) 
# just like SFrames 2 numpy arrays can be elementwise subtracted with '-': 
errors = test_predictions - example_output # prediction errors in this case is just the -example_output
feature = example_features[:,0] # let's compute the derivative with respect to 'constant', the ":" indicates "all rows"
derivative = feature_derivative(errors, feature)
print derivative
print -np.sum(example_output)*2 # should be the same as derivative
# Out:
# [-221900. -538000. -180000. ..., -402101. -400000. -325000.]
# [ 1.  1.  1. ...,  1.  1.  1.]
# -23345850022.0
# -23345850022.0

# %% [markdown]
# # Gradient Descent

# %% [markdown]
# Now we will write a function that performs a gradient descent. The basic premise is simple. Given a starting point we update the current weights by moving in the negative gradient direction. Recall that the gradient is the direction of *increase* and therefore the negative gradient is the direction of *decrease* and we're trying to *minimize* a cost function.
#
# The amount by which we move in the negative gradient *direction*  is called the 'step size'. We stop when we are 'sufficiently close' to the optimum. We define this by requiring that the magnitude (length) of the gradient vector to be smaller than a fixed 'tolerance'.
#
# With this in mind, complete the following gradient descent function below using your derivative function above. For each step in the gradient descent we update the weight for each feature befofe computing our stopping criteria

# %%
from math import sqrt # recall that the magnitude/length of a vector [g[0], g[1], g[2]] is sqrt(g[0]^2 + g[1]^2 + g[2]^2)

# %%
def regression_gradient_descent(feature_matrix, output, initial_weights, step_size, tolerance):
    print "Feature Matrix: "
    print feature_matrix, len(feature_matrix)
    print "output: "
    print output, len(output)
    print "Initial Weights: "
    
    
    converged = False 
    weights = np.array(initial_weights) # make sure it's a numpy array
    print "weights: "
    print weights, len(weights)
    
    while not converged:
        print "START===================================================================START"
        # compute the predictions based on feature_matrix and weights using your predict_output() function
        predictions = predict_output(feature_matrix, weights)
        print "Predictions: "
        print predictions
        print len(predictions)
        
        # compute the errors as predictions - output
        errors = predictions - output
        #print "Errors: "
        #print errors
        #print len(errors)
        
        gradient_sum_squares = 0 # initialize the gradient sum of squares
        # while we haven't reached the tolerance yet, update each feature's weight
        for i in range(len(weights)): # loop over each weight
            print "START-----------------------------------------------------------------START"
            # Recall that feature_matrix[:, i] is the feature column associated with weights[i]
            # compute the derivative for weight[i]:
            derivative = feature_derivative(errors, feature_matrix[:, i])
            print "derivative"
            print derivative
            
            # add the squared value of the derivative to the gradient magnitude (for assessing convergence)
            print "gradient_sum_squares"
            print gradient_sum_squares
            gradient_sum_squares = gradient_sum_squares + (derivative * derivative)
            print "gradient_sum_squares"
            print gradient_sum_squares
            
            # subtract the step size times the derivative from the current weight
            weights[i] = weights[i] - (step_size * derivative)
            print "modified weights"
            print weights[i]
            print "END-------------------------------------------------------------------END"
            
        # compute the square-root of the gradient sum of squares to get the gradient matnigude:
        gradient_magnitude = sqrt(gradient_sum_squares)
        if gradient_magnitude < tolerance:
            converged = True
        print "END===================================================================END"    
    return(weights)

# %% [markdown]
# A few things to note before we run the gradient descent. Since the gradient is a sum over all the data points and involves a product of an error and a feature the gradient itself will be very large since the features are large (squarefeet) and the output is large (prices). So while you might expect "tolerance" to be small, small is only relative to the size of the features.
#
# For similar reasons the step size will be much smaller than you might expect but this is because the gradient has such large values.

# %% [markdown]
# # Running the Gradient Descent as Simple Regression

# %% [markdown]
# First let's split the data into training and test data.

# %%
train_data,test_data = sales.random_split(.8,seed=0)

# %% [markdown]
# Although the gradient descent is designed for multiple regression since the constant is now a feature we can use the gradient descent function to estimat the parameters in the simple regression on squarefeet. The folowing cell sets up the feature_matrix, output, initial weights and step size for the first model:

# %%
# let's test out the gradient descent
simple_features = ['sqft_living']
my_output = 'price'
(simple_feature_matrix, output) = get_numpy_data(train_data, simple_features, my_output)
initial_weights = np.array([-47000., 1.])
step_size = 7e-12
tolerance = 2.5e7

# %% [markdown]
# Next run your gradient descent with the above parameters.

# %%
weights = regression_gradient_descent(simple_feature_matrix, output, initial_weights, step_size, tolerance)
print weights
# Out:
# Feature Matrix:
# [[  1.00000000e+00   1.18000000e+03]
#  [  1.00000000e+00   2.57000000e+03]
#  [  1.00000000e+00   7.70000000e+02]
#  ...,
#  [  1.00000000e+00   1.53000000e+03]
#  [  1.00000000e+00   1.60000000e+03]
#  [  1.00000000e+00   1.02000000e+03]] 17384
# output:
# [ 221900.  538000.  180000. ...,  360000.  400000.  325000.] 17384
# Initial Weights:
# weights:
# [ -4.70000000e+04   1.00000000e+00] 2
# START===================================================================START
# Predictions:
# [-45820. -44430. -46230. ..., -45470. -45400. -45980.]
# 17384
# START-----------------------------------------------------------------START
# derivative
# -20314476464.0
# gradient_sum_squares
# 0
# gradient_sum_squares
# 4.12677954006e+20
# modified weights
# -46999.8577987
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -5.05515266926e+13
# gradient_sum_squares
# 4.12677954006e+20
# gradient_sum_squares
# 2.55545726363e+27
# modified weights
# 354.860686848
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 371735.75268253  864992.10740189  226242.87107465 ...,  495936.99307949
#   520777.24115888  314958.04278677]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 5276190530.64
# gradient_sum_squares
# 0
# gradient_sum_squares
# 2.78381865157e+19
# modified weights
# -46999.894732
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 1.31274499632e+13
# gradient_sum_squares
# 2.78381865157e+19
# gradient_sum_squares
# 1.72329970376e+26
# modified weights
# 262.968537106
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 263302.97905279  628829.24562979  155485.87883943 ...,  355341.9670398
#   373749.76463721  221228.01311587]
# 17384
# START-----------------------------------------------------------------START
# derivative
# -1369310060.29
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.87501004121e+18
# modified weights
# -46999.8851468
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -3.40899580752e+12
# gradient_sum_squares
# 1.87501004121e+18
# gradient_sum_squares
# 1.16212542907e+25
# modified weights
# 286.831507758
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 291461.29400806  690157.08979222  173860.37582713 ...,  391852.3217235
#   411930.52726658  245568.25276672]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 356423704.768
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.27037857321e+17
# modified weights
# -46999.8876418
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 885263508348.0
# gradient_sum_squares
# 1.27037857321e+17
# gradient_sum_squares
# 7.83691606251e+23
# modified weights
# 280.6346632
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 284149.01493414  674231.19678206  169088.80302216 ...,  382371.14705412
#   402015.57347812  239247.46882215]
# 17384
# START-----------------------------------------------------------------START
# derivative
# -91722674.4832
# gradient_sum_squares
# 0
# gradient_sum_squares
# 8.41304901436e+15
# modified weights
# -46999.8869997
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -229889247422.0
# gradient_sum_squares
# 8.41304901436e+15
# gradient_sum_squares
# 5.28490744932e+22
# modified weights
# 282.243887932
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 286047.9007599   678366.90498524  170327.90670783 ...,  384833.26153607
#   404590.3336913   240888.8786908 ]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 24654011.9039
# gradient_sum_squares
# 0
# gradient_sum_squares
# 6.07820302957e+14
# modified weights
# -46999.8871723
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 59698683168.9
# gradient_sum_squares
# 6.07820302957e+14
# gradient_sum_squares
# 3.56393337992e+21
# modified weights
# 281.82599715
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 285554.78946435  677292.92550245  170006.13063297 ...,  384193.88846675
#   403921.70826723  240462.6299204 ]
# 17384
# START-----------------------------------------------------------------START
# derivative
# -5567214.41928
# gradient_sum_squares
# 0
# gradient_sum_squares
# 3.09938763902e+13
# modified weights
# -46999.8871333
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -15502825422.5
# gradient_sum_squares
# 3.09938763902e+13
# gradient_sum_squares
# 2.40337627074e+20
# modified weights
# 281.934516928
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 285682.84284131  677571.82137077  170089.69090096 ...,  384359.92376599
#   404095.33995093  240573.32013288]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 2280770.80818
# gradient_sum_squares
# 0
# gradient_sum_squares
# 5.20191547945e+12
# modified weights
# -46999.8871493
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 4025843755.44
# gradient_sum_squares
# 5.20191547945e+12
# gradient_sum_squares
# 1.62074231451e+19
# modified weights
# 281.906336021
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 285649.58935592  677499.39642565  170067.99158716 ...,  384316.80696341
#   404050.25048491  240544.5755925 ]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 242770.339852
# gradient_sum_squares
# 0
# gradient_sum_squares
# 58937437912.0
# modified weights
# -46999.887151
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -1045449719.97
# gradient_sum_squares
# 58937437912.0
# gradient_sum_squares
# 1.09296517593e+18
# modified weights
# 281.913654169
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 285658.22476891  677518.20406441  170073.62655945 ...,  384328.00372821
#   404061.95952007  240552.0401018 ]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 772007.520968
# gradient_sum_squares
# 0
# gradient_sum_squares
# 595995612431.0
# modified weights
# -46999.8871564
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 271486794.211
# gradient_sum_squares
# 595995612431.0
# gradient_sum_squares
# 7.37056754266e+16
# modified weights
# 281.911753762
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 285655.98228259  677513.32001158  170072.16324022 ...,  384325.09609924
#   404058.91886257  240550.10168069]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 634572.773602
# gradient_sum_squares
# 0
# gradient_sum_squares
# 402682604997.0
# modified weights
# -46999.8871609
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -70501258.901
# gradient_sum_squares
# 402682604997.0
# gradient_sum_squares
# 4.97083018924e+15
# modified weights
# 281.912247271
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 285656.56461854  677514.58832478  170072.54323757 ...,  384325.85116328
#   404059.70847223  240550.60505524]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 670262.419427
# gradient_sum_squares
# 0
# gradient_sum_squares
# 449251710896.0
# modified weights
# -46999.8871655
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 18307751.4198
# gradient_sum_squares
# 449251710896.0
# gradient_sum_squares
# 3.3562301376e+14
# modified weights
# 281.912119116
# END-------------------------------------------------------------------END
# END===================================================================END
# [-46999.88716555    281.91211912]

# %% [markdown]
# How do your weights compare to those achieved in week 1 (don't expect them to be exactly the same)?
#
# **Quiz Question: What is the value of the weight for sqft_living -- the second element of ‘simple_weights’ (rounded to 1 decimal place)?**

# %% [markdown]
# Use your newly estimated weights and your predict_output() function to compute the predictions on all the TEST data (you will need to create a numpy array of the test feature_matrix and test output first:

# %%
(test_simple_feature_matrix, test_output) = get_numpy_data(test_data, simple_features, my_output)

# %% [markdown]
# Now compute your predictions using test_simple_feature_matrix and your weights from above.

# %%
model1_predictions = predict_output(test_simple_feature_matrix, weights)
model1_predictions
# Out:
# array([ 356134.44317093,  784640.86422788,  435069.83652353, ...,
#         663418.65300782,  604217.10799338,  240550.4743332 ])

# %% [markdown]
# **Quiz Question: What is the predicted price for the 1st house in the TEST data set for model 1 (round to nearest dollar)?**

# %%
model1_predictions[0]
test_output[0]
print model1_predictions[0] - test_output[0]
# Out:
# 46134.4431709

# %% [markdown]
# Now that you have the predictions on test data, compute the RSS on the test data set. Save this value for comparison later. Recall that RSS is the sum of the squared errors (difference between prediction and output).

# %%
errors = model1_predictions - test_output
errors_squared = errors * errors
rss_model1 = sum(errors_squared)
rss_model1
# Out:
# 275400047593155.69

# %% [markdown]
# # Running a multiple regression

# %% [markdown]
# Now we will use more than one actual feature. Use the following code to produce the weights for a second model with the following parameters:

# %%
model_features = ['sqft_living', 'sqft_living15'] # sqft_living15 is the average squarefeet for the nearest 15 neighbors. 
my_output = 'price'
(feature_matrix, output) = get_numpy_data(train_data, model_features, my_output)
initial_weights = np.array([-100000., 1., 1.])
step_size = 4e-12
tolerance = 1e9

# %% [markdown]
# Use the above parameters to estimate the model weights. Record these values for your quiz.

# %%
weights_model2 = regression_gradient_descent(feature_matrix, output, initial_weights, step_size, tolerance)
print weights_model2
# Out:
# Feature Matrix:
# [[  1.00000000e+00   1.18000000e+03   1.34000000e+03]
#  [  1.00000000e+00   2.57000000e+03   1.69000000e+03]
#  [  1.00000000e+00   7.70000000e+02   2.72000000e+03]
#  ...,
#  [  1.00000000e+00   1.53000000e+03   1.53000000e+03]
#  [  1.00000000e+00   1.60000000e+03   1.41000000e+03]
#  [  1.00000000e+00   1.02000000e+03   1.02000000e+03]] 17384
# output:
# [ 221900.  538000.  180000. ...,  360000.  400000.  325000.] 17384
# Initial Weights:
# weights:
# [ -1.00000000e+05   1.00000000e+00   1.00000000e+00] 3
# START===================================================================START
# Predictions:
# [-97480. -95740. -96510. ..., -96940. -96990. -97960.]
# 17384
# START-----------------------------------------------------------------START
# derivative
# -22088131390.0
# gradient_sum_squares
# 0
# gradient_sum_squares
# 4.87885548302e+20
# modified weights
# -99999.9116475
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -5.42241456313e+13
# gradient_sum_squares
# 4.87885548302e+20
# gradient_sum_squares
# 2.94025845733e+27
# modified weights
# 217.896582525
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -4.89822593371e+13
# gradient_sum_squares
# 2.94025845733e+27
# gradient_sum_squares
# 5.33952018709e+27
# modified weights
# 196.929037348
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 421002.96577892  792804.3785608   603427.43848423 ...,  534683.2867589
#   526304.56305387  323122.22062344]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 7126218409.31
# gradient_sum_squares
# 0
# gradient_sum_squares
# 5.07829888172e+19
# modified weights
# -99999.9401523
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 1.62070050891e+13
# gradient_sum_squares
# 5.07829888172e+19
# gradient_sum_squares
# 2.6266706474e+26
# modified weights
# 153.068562169
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 1.58558470033e+13
# gradient_sum_squares
# 2.6266706474e+26
# gradient_sum_squares
# 5.14074948933e+26
# modified weights
# 133.505649335
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 259518.53331584  519010.81199792  380998.2189088  ...,  338458.60344862
#   333152.72488025  192305.75558163]
# 17384
# START-----------------------------------------------------------------START
# derivative
# -1941371779.99
# gradient_sum_squares
# 0
# gradient_sum_squares
# 3.76892438813e+18
# modified weights
# -99999.9323869
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -5.62333413279e+12
# gradient_sum_squares
# 3.76892438813e+18
# gradient_sum_squares
# 3.16218905379e+25
# modified weights
# 175.5618987
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -4.27000346518e+12
# gradient_sum_squares
# 3.16218905379e+25
# gradient_sum_squares
# 4.98548201306e+25
# modified weights
# 150.585663196
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 308947.89676147  605683.9180731   444775.73350445 ...,  399005.83731368
#   393224.89063921  232670.58074683]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 864671224.15
# gradient_sum_squares
# 0
# gradient_sum_squares
# 7.47656325873e+17
# modified weights
# -99999.9358455
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 1.16169158388e+12
# gradient_sum_squares
# 7.47656325873e+17
# gradient_sum_squares
# 1.34952808371e+24
# modified weights
# 170.915132365
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 1.95683475947e+12
# gradient_sum_squares
# 1.34952808371e+24
# gradient_sum_squares
# 5.17873035957e+24
# modified weights
# 142.758324158
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 292976.07471613  580513.52215816  419907.35778441 ...,  379920.45263373
#   374753.51300031  219946.9898073 ]
# 17384
# START-----------------------------------------------------------------START
# derivative
# -11846421.7952
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.4033770935e+14
# modified weights
# -99999.9357982
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -928924532386.0
# gradient_sum_squares
# 1.4033770935e+14
# gradient_sum_squares
# 8.62900787009e+23
# modified weights
# 174.630830494
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 10520528506.5
# gradient_sum_squares
# 8.62900787009e+23
# gradient_sum_squares
# 8.63011468529e+23
# modified weights
# 142.716242044
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 297304.20852359  589991.74762577  422653.98204139 ...,  385541.08518485
#   380639.29427419  223694.07819052]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 253961437.694
# gradient_sum_squares
# 0
# gradient_sum_squares
# 6.44964118359e+16
# modified weights
# -99999.936814
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -267010493601.0
# gradient_sum_squares
# 6.44964118359e+16
# gradient_sum_squares
# 7.12946681894e+22
# modified weights
# 175.698872469
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 599537128254.0
# gradient_sum_squares
# 7.12946681894e+22
# gradient_sum_squares
# 4.30739436344e+23
# modified weights
# 140.318093531
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 295350.9780301   588683.74349714  416953.40939044 ...,  383506.02116493
#   378966.77101404  222337.36850529]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 165610625.45
# gradient_sum_squares
# 0
# gradient_sum_squares
# 2.74268792619e+16
# modified weights
# -99999.9374764
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -459137878334.0
# gradient_sum_squares
# 2.74268792619e+16
# gradient_sum_squares
# 2.10807618748e+23
# modified weights
# 177.535423982
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 402546257133.0
# gradient_sum_squares
# 2.10807618748e+23
# gradient_sum_squares
# 3.7285110788e+23
# modified weights
# 138.707908502
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 295360.46021516  590682.46752576  413987.85011566 ...,  383852.36122424
#   379634.89188271  222568.26165735]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 187245405.404
# gradient_sum_squares
# 0
# gradient_sum_squares
# 3.50608418449e+16
# modified weights
# -99999.9382254
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -386689337854.0
# gradient_sum_squares
# 3.50608418449e+16
# gradient_sum_squares
# 1.49528679071e+23
# modified weights
# 179.082181333
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 449681823946.0
# gradient_sum_squares
# 1.49528679071e+23
# gradient_sum_squares
# 3.51742421858e+23
# modified weights
# 136.909181206
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 294775.3385645   591617.78404005  410286.31428274 ...,  383466.84646038
#   379573.49740894  222311.25156511]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 174904044.14
# gradient_sum_squares
# 0
# gradient_sum_squares
# 3.05914246564e+16
# modified weights
# -99999.938925
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -396606422958.0
# gradient_sum_squares
# 3.05914246564e+16
# gradient_sum_squares
# 1.57296685323e+23
# modified weights
# 180.668607025
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 421430725824.0
# gradient_sum_squares
# 1.57296685323e+23
# gradient_sum_squares
# 3.34900541992e+23
# modified weights
# 135.223458303
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 294388.45149083  592846.02566186  406922.69506887 ...,  383314.92102722
#   379734.9085226   222209.9677098 ]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 173234286.778
# gradient_sum_squares
# 0
# gradient_sum_squares
# 3.00101181156e+16
# modified weights
# -99999.939618
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -381274935306.0
# gradient_sum_squares
# 3.00101181156e+16
# gradient_sum_squares
# 1.45370606303e+23
# modified weights
# 182.193706766
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 416884889043.0
# gradient_sum_squares
# 1.45370606303e+23
# gradient_sum_squares
# 3.19163617015e+23
# modified weights
# 133.555918747
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 293953.56548726  593947.38945394  403561.31358388 ...,  383096.98741741
#   379823.83664142  222064.67840561]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 168385074.257
# gradient_sum_squares
# 0
# gradient_sum_squares
# 2.83535332324e+16
# modified weights
# -99999.9402915
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -374065293968.0
# gradient_sum_squares
# 2.83535332324e+16
# gradient_sum_squares
# 1.39924872505e+23
# modified weights
# 183.689967942
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 405302411297.0
# gradient_sum_squares
# 1.39924872505e+23
# gradient_sum_squares
# 3.04194917108e+23
# modified weights
# 131.934709102
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 293546.7320767   595052.93570203  400303.74378086 ...,  382905.81558582
#   379931.94824956  221937.23029337]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 164649339.053
# gradient_sum_squares
# 0
# gradient_sum_squares
# 2.71094048507e+16
# modified weights
# -99999.9409501
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -364620472137.0
# gradient_sum_squares
# 2.71094048507e+16
# gradient_sum_squares
# 1.32948115811e+23
# modified weights
# 185.148449831
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 396210671100.0
# gradient_sum_squares
# 1.32948115811e+23
# gradient_sum_squares
# 2.89931011704e+23
# modified weights
# 130.349866417
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 293144.0508495   596122.84936036  397116.00207487 ...,  382712.48290957
#   380030.89042764  221808.34162301]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 160692569.23
# gradient_sum_squares
# 0
# gradient_sum_squares
# 2.58221018058e+16
# modified weights
# -99999.9415929
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -356146056912.0
# gradient_sum_squares
# 2.58221018058e+16
# gradient_sum_squares
# 1.26840039676e+23
# modified weights
# 186.573034058
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 386647354676.0
# gradient_sum_squares
# 1.26840039676e+23
# gradient_sum_squares
# 2.76336216554e+23
# modified weights
# 128.803276999
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 292752.62977429  597170.29406504  394006.20806852 ...,  382525.81432449
#   380129.53346873  221683.89568536]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 156925725.694
# gradient_sum_squares
# 0
# gradient_sum_squares
# 2.46256833846e+16
# modified weights
# -99999.9422206
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -347641231744.0
# gradient_sum_squares
# 2.46256833846e+16
# gradient_sum_squares
# 1.20854450634e+23
# modified weights
# 187.963598985
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 377524109204.0
# gradient_sum_squares
# 1.20854450634e+23
# gradient_sum_squares
# 2.63378903664e+23
# modified weights
# 127.293180562
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 292369.96653508  598191.98232144  390969.48012645 ...,  382342.93048673
#   380225.20074828  221561.97291762]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 153218465.649
# gradient_sum_squares
# 0
# gradient_sum_squares
# 2.3475898216e+16
# modified weights
# -99999.9428335
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -339409989019.0
# gradient_sum_squares
# 2.3475898216e+16
# gradient_sum_squares
# 1.15199164122e+23
# modified weights
# 189.321238941
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 368551208365.0
# gradient_sum_squares
# 1.15199164122e+23
# gradient_sum_squares
# 2.51029157309e+23
# modified weights
# 125.818975728
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 291996.54659354  599189.71022714  388005.02513274 ...,  382164.58561146
#   380318.79524995  221443.07612981]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 149608404.708
# gradient_sum_squares
# 0
# gradient_sum_squares
# 2.23826747593e+16
# modified weights
# -99999.9434319
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -331351775524.0
# gradient_sum_squares
# 2.23826747593e+16
# gradient_sum_squares
# 1.09794021526e+23
# modified weights
# 190.646646044
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 359811707747.0
# gradient_sum_squares
# 1.09794021526e+23
# gradient_sum_squares
# 2.39258486557e+23
# modified weights
# 124.379728897
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 291631.93562206  600163.67873673  385110.83662264 ...,  381990.41022782
#   380410.10798318  221326.95900791]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 146081131.414
# gradient_sum_squares
# 0
# gradient_sum_squares
# 2.13396969552e+16
# modified weights
# -99999.9440162
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -323491660105.0
# gradient_sum_squares
# 2.13396969552e+16
# gradient_sum_squares
# 1.04646875497e+23
# modified weights
# 191.940612684
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 351273202835.0
# gradient_sum_squares
# 1.04646875497e+23
# gradient_sum_squares
# 2.28039738527e+23
# modified weights
# 122.974636086
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 291275.99130624  601114.56556712  382285.33790459 ...,  381820.38660199
#   380499.27315954  221213.60972925]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 142638436.082
# gradient_sum_squares
# 0
# gradient_sum_squares
# 2.03457234478e+16
# modified weights
# -99999.9445868
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -315815893998.0
# gradient_sum_squares
# 2.03457234478e+16
# gradient_sum_squares
# 9.97396992476e+22
# modified weights
# 193.20387626
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 342939257716.0
# gradient_sum_squares
# 9.97396992476e+22
# gradient_sum_squares
# 2.1734703373e+23
# modified weights
# 121.602879055
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 290928.487334    602042.88300471  379526.87116361 ...,  381654.39104549
#   380586.31689706  221102.94583473]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 139277147.48
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.93981238102e+16
# modified weights
# -99999.9451439
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -308322909788.0
# gradient_sum_squares
# 1.93981238102e+16
# gradient_sum_squares
# 9.50630360985e+22
# modified weights
# 194.437167899
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 334802434400.0
# gradient_sum_squares
# 9.50630360985e+22
# gradient_sum_squares
# 2.07155706178e+23
# modified weights
# 120.263669318
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 290589.22986271  602949.17750369  376833.85468238 ...,  381492.33579776
#   380671.29723259  220994.90881721]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 135995695.312
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.84948291433e+16
# modified weights
# -99999.9456879
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -301007500274.0
# gradient_sum_squares
# 1.84948291433e+16
# gradient_sum_squares
# 9.06055337163e+22
# modified weights
# 195.6411979
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 326858857535.0
# gradient_sum_squares
# 9.06055337163e+22
# gradient_sum_squares
# 1.97442246466e+23
# modified weights
# 118.956233887
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 290258.02124364  603833.96818559  374204.73286926 ...,  381334.12494734
#   380754.26073386  220889.4347356 ]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 132792073.33
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.76337347392e+16
# modified weights
# -99999.946219
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -293865722248.0
# gradient_sum_squares
# 1.76337347392e+16
# gradient_sum_squares
# 8.63570803463e+22
# modified weights
# 196.816660789
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 319103693471.0
# gradient_sum_squares
# 8.63570803463e+22
# gradient_sum_squares
# 1.88184247533e+23
# modified weights
# 117.679819114
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 289934.67112448  604697.76631127  371637.99057765 ...,  381179.66803229
#   380835.25599391  220786.46328185]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 129664469.658
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.68128746916e+16
# modified weights
# -99999.9467377
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -286893372341.0
# gradient_sum_squares
# 1.68128746916e+16
# gradient_sum_squares
# 8.2307823906e+22
# modified weights
# 197.964234279
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 311532548983.0
# gradient_sum_squares
# 8.2307823906e+22
# gradient_sum_squares
# 1.79360352982e+23
# modified weights
# 116.433688918
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 289618.99286072  605541.06962915  369132.14751287 ...,  381028.87575258
#   380914.32948197  220685.93492249]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 126611069.885
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.60303630175e+16
# modified weights
# -99999.9472441
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -280086456622.0
# gradient_sum_squares
# 1.60303630175e+16
# gradient_sum_squares
# 7.84484392134e+22
# modified weights
# 199.084580105
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 304141034051.0
# gradient_sum_squares
# 7.84484392134e+22
# gradient_sum_squares
# 1.70950207807e+23
# modified weights
# 115.217124781
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 289310.80448702  606364.3645066   366685.75884235 ...,  380881.66123228
#   380991.52686586  220587.79174014]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 123630116.772
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.52844057731e+16
# modified weights
# -99999.9477387
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -273441041896.0
# gradient_sum_squares
# 1.52844057731e+16
# gradient_sum_squares
# 7.47700186774e+22
# modified weights
# 200.178344273
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 296924894148.0
# gradient_sum_squares
# 7.47700186774e+22
# gradient_sum_squares
# 1.62934411442e+23
# modified weights
# 114.029425205
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 289009.92827761  607168.12563832  364297.41390854 ...,  380737.93956197
#   381066.89263647  220491.97712843]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 120719890.39
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.45732919357e+16
# modified weights
# -99999.9482215
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -266953298840.0
# gradient_sum_squares
# 1.45732919357e+16
# gradient_sum_squares
# 7.12640783349e+22
# modified weights
# 201.246157468
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 289879965975.0
# gradient_sum_squares
# 7.12640783349e+22
# gradient_sum_squares
# 1.55294473009e+23
# modified weights
# 112.869905341
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 288716.19074763  607952.81649753  361965.73555627 ...,  380597.62787622
#   381140.47025807  220398.43584363]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 117878712.977
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.38953909731e+16
# modified weights
# -99999.9486931
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -260619485715.0
# gradient_sum_squares
# 1.38953909731e+16
# gradient_sum_squares
# 6.792253023e+22
# modified weights
# 202.288635411
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 283002188025.0
# gradient_sum_squares
# 6.792253023e+22
# gradient_sum_squares
# 1.48012768657e+23
# modified weights
# 111.737896589
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 288429.42252088  608718.88954812  359689.37929505 ...,  380460.64526657
#   381212.30215467  220307.1139467 ]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 115104946.158
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.324914863e+16
# modified weights
# -99999.9491535
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -254435950575.0
# gradient_sum_squares
# 1.324914863e+16
# gradient_sum_squares
# 6.47376661942e+22
# modified weights
# 203.306379213
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 276287594220.0
# gradient_sum_squares
# 6.47376661942e+22
# gradient_sum_squares
# 1.41072500914e+23
# modified weights
# 110.632746212
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 288149.45824215  609466.78652268  357467.03253729 ...,  380326.91274705
#   381282.42974653  220217.95878021]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 112396990.559
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.26330834867e+16
# modified weights
# -99999.9496031
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -248399127804.0
# gradient_sum_squares
# 1.26330834867e+16
# gradient_sum_squares
# 6.1702139327e+22
# modified weights
# 204.299975724
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 269732312874.0
# gradient_sum_squares
# 6.1702139327e+22
# gradient_sum_squares
# 1.34457659935e+23
# modified weights
# 109.55381696
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 287876.1364788   610196.93867189  355297.41383727 ...,  380196.35320483
#   381350.89347028  220130.91893553]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 109753284.714
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.20457835056e+16
# modified weights
# -99999.9500421
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -242505536485.0
# gradient_sum_squares
# 1.20457835056e+16
# gradient_sum_squares
# 5.88089472716e+22
# modified weights
# 205.26999787
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 263332564071.0
# gradient_sum_squares
# 5.88089472716e+22
# gradient_sum_squares
# 1.28152986572e+23
# modified weights
# 108.500486704
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 287609.29962857  610909.76701483  353179.27215354 ...,  380068.89135699
#   381417.73280341  220045.94422397]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 107172304.219
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.14859027916e+16
# modified weights
# -99999.9504708
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -236751778258.0
# gradient_sum_squares
# 1.14859027916e+16
# gradient_sum_squares
# 5.60514159943e+22
# modified weights
# 206.217004983
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 257084657606.0
# gradient_sum_squares
# 5.60514159943e+22
# gradient_sum_squares
# 1.2214393717e+23
# modified weights
# 107.472148074
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 287348.7938285   611605.68258122  351111.38612714 ...,  379944.4537067
#   381482.98628668  219962.98564754]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 104652560.831
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.09521584884e+16
# modified weights
# -99999.9508894
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -231134535405.0
# gradient_sum_squares
# 1.09521584884e+16
# gradient_sum_squares
# 5.3423184409e+22
# modified weights
# 207.141543125
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 250984990820.0
# gradient_sum_squares
# 5.3423184409e+22
# gradient_sum_squares
# 1.16416650026e+23
# modified weights
# 106.468208111
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 287094.4688662   612285.08664863  349092.56337745 ...,  379822.96850095
#   381546.69154644  219881.99537084]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 102192601.621
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.0443327826e+16
# modified weights
# -99999.9512981
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -225650568920.0
# gradient_sum_squares
# 1.0443327826e+16
# gradient_sum_squares
# 5.09181896973e+22
# modified weights
# 208.044145401
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 245030046537.0
# gradient_sum_squares
# 5.09181896973e+22
# gradient_sum_squares
# 1.10957913403e+23
# modified weights
# 105.488087924
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 286846.17809329  612948.37097376  347121.63981463 ...,  379704.36568916
#   381608.88531628  219802.92669339]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 99791008.1315
# gradient_sum_squares
# 0
# gradient_sum_squares
# 9.95824530391e+15
# modified weights
# -99999.9516973
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -220296716649.0
# gradient_sum_squares
# 9.95824530391e+15
# gradient_sum_squares
# 4.85306533247e+22
# modified weights
# 208.925332267
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 239216391027.0
# gradient_sum_squares
# 4.85306533247e+22
# gradient_sum_squares
# 1.05755135061e+23
# modified weights
# 104.53122236
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 286603.77834081  613595.91801841  345197.47896837 ...,  379588.5768828
#   381669.60345828  219725.73402276]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 97446395.5609
# gradient_sum_squares
# 0
# gradient_sum_squares
# 9.49580000781e+15
# modified weights
# -99999.9520871
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -215069891464.0
# gradient_sum_squares
# 9.49580000781e+15
# gradient_sum_squares
# 4.62550677102e+22
# modified weights
# 209.785611833
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 233540672030.0
# gradient_sum_squares
# 4.62550677102e+22
# gradient_sum_squares
# 1.00796313203e+23
# modified weights
# 103.597059672
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 286367.12983665  614228.10116995  343318.9713326  ...,  379475.53531595
#   381728.88098362  219650.37284827]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 95157411.9626
# gradient_sum_squares
# 0
# gradient_sum_squares
# 9.05493305142e+15
# modified weights
# -99999.9524677
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -209967079482.0
# gradient_sum_squares
# 9.05493305142e+15
# gradient_sum_squares
# 4.40861835213e+22
# modified weights
# 210.625480151
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 227999616824.0
# gradient_sum_squares
# 4.40861835213e+22
# gradient_sum_squares
# 9.60700087934e+22
# modified weights
# 102.685061205
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 286136.096125    614845.28495667  341485.03372573 ...,  379365.17580679
#   381786.75207278  219576.79971528]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 92922737.4672
# gradient_sum_squares
# 0
# gradient_sum_squares
# 8.6346351384e+15
# modified weights
# -99999.9528394
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -204985338330.0
# gradient_sum_squares
# 8.6346351384e+15
# gradient_sum_squares
# 4.20189975648e+22
# modified weights
# 211.445421504
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 222590030337.0
# gradient_sum_squares
# 4.20189975648e+22
# gradient_sum_squares
# 9.15653191701e+22
# modified weights
# 101.794701083
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 285910.54398762  615447.82525793  339694.60866603 ...,  379257.43472002
#   381843.25009531  219504.97220021]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 90741083.5208
# gradient_sum_squares
# 0
# gradient_sum_squares
# 8.23394423853e+15
# modified weights
# -99999.9532024
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -200121795444.0
# gradient_sum_squares
# 8.23394423853e+15
# gradient_sum_squares
# 4.00487412458e+22
# modified weights
# 212.245908686
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 217308793301.0
# gradient_sum_squares
# 4.00487412458e+22
# gradient_sum_squares
# 8.72718528917e+22
# modified weights
# 100.92546591
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 285690.34336706  616036.06950942  337946.66376192 ...,  379152.24993017
#   381898.40762897  219434.84888599]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 88611192.1421
# gradient_sum_squares
# 0
# gradient_sum_squares
# 7.85194337285e+15
# modified weights
# -99999.9535568
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -195373646419.0
# gradient_sum_squares
# 7.85194337285e+15
# gradient_sum_squares
# 3.81708695669e+22
# modified weights
# 213.027403272
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 212152860460.0
# gradient_sum_squares
# 3.81708695669e+22
# gradient_sum_squares
# 8.31797057683e+22
# modified weights
# 100.076854468
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 285475.36729165  616610.35690345  336240.19111664 ...,  379049.56078579
#   381952.25647861  219366.38933825]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 86531835.1972
# gradient_sum_squares
# 0
# gradient_sum_squares
# 7.48775850259e+15
# modified weights
# -99999.953903
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -190738153384.0
# gradient_sum_squares
# 7.48775850259e+15
# gradient_sum_squares
# 3.63810506441e+22
# modified weights
# 213.790355885
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 207119258810.0
# gradient_sum_squares
# 3.63810506441e+22
# gradient_sum_squares
# 7.92794380141e+22
# modified weights
# 99.2483774332
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 285265.49180227  617171.01858455  334574.20674708 ...,  378949.30807446
#   382004.82769445  219299.55408199]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 84501813.691
# gradient_sum_squares
# 0
# gradient_sum_squares
# 7.14055651706e+15
# modified weights
# -99999.954241
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -186212643431.0
# gradient_sum_squares
# 7.14055651706e+15
# gradient_sum_squares
# 3.4675155714e+22
# modified weights
# 214.535206459
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 202205085885.0
# gradient_sum_squares
# 3.4675155714e+22
# gradient_sum_squares
# 7.55620524716e+22
# modified weights
# 98.4395570897
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 285060.59588091  617718.37784043  332947.75001642 ...,  378851.43398863
#   382056.15159001  219234.30457877]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 82519957.0763
# gradient_sum_squares
# 0
# gradient_sum_squares
# 6.80954331587e+15
# modified weights
# -99999.954571
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -181794507068.0
# gradient_sum_squares
# 6.80954331587e+15
# gradient_sum_squares
# 3.30492496095e+22
# modified weights
# 215.262384487
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 197407508082.0
# gradient_sum_squares
# 3.30492496095e+22
# gradient_sum_squares
# 7.20189738568e+22
# modified weights
# 97.6499270573
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 284860.56138087  618252.75028837  331359.88308017 ...,  378755.88209234
#   382106.25775958  219170.60320455]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 80585122.5786
# gradient_sum_squares
# 0
# gradient_sum_squares
# 6.49396198101e+15
# modified weights
# -99999.9548934
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -177481196717.0
# gradient_sum_squares
# 6.49396198101e+15
# gradient_sum_squares
# 3.14995816822e+22
# modified weights
# 215.972309274
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 192723759032.0
# gradient_sum_squares
# 3.14995816822e+22
# gradient_sum_squares
# 6.86420289778e+22
# modified weights
# 96.8790320212
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 284665.27295862  618774.44405723  329809.69034545 ...,  378662.59728863
#   382155.17509529  219108.41322796]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 78696194.5373
# gradient_sum_squares
# 0
# gradient_sum_squares
# 6.19309103466e+15
# modified weights
# -99999.9552082
# ...
# derivative
# 1026932838.46
# gradient_sum_squares
# 8.94374851643e+17
# gradient_sum_squares
# 1.94896590634e+18
# modified weights
# 65.3277834807
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 276672.49374812  640126.36491151  266363.28801087 ...,  374844.62975392
#   384157.26716512  216563.09691111]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 1386005.93983
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.92101246523e+12
# modified weights
# -99999.9687801
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -923274642.819
# gradient_sum_squares
# 1.92101246523e+12
# gradient_sum_squares
# 8.52437987085e+17
# modified weights
# 245.031856368
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 1002567515.67
# gradient_sum_squares
# 8.52437987085e+17
# gradient_sum_squares
# 1.85757961056e+18
# modified weights
# 65.3237732107
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 276671.47783701  640129.07881289  266355.22375666 ...,  374844.14447599
#   384157.52163651  216562.77339065]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 1376179.53622
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.8938701159e+12
# modified weights
# -99999.9687856
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -901368755.449
# gradient_sum_squares
# 1.8938701159e+12
# gradient_sum_squares
# 8.12467527169e+17
# modified weights
# 245.035461843
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 978780291.759
# gradient_sum_squares
# 8.12467527169e+17
# gradient_sum_squares
# 1.7704783867e+18
# modified weights
# 65.3198580895
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 276670.48602967  640131.72832342  266347.35083734 ...,  374843.67071189
#   384157.77007019  216562.45754607]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 1366586.27643
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.86755805092e+12
# modified weights
# -99999.968791
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -879982613.666
# gradient_sum_squares
# 1.86755805092e+12
# gradient_sum_squares
# 7.74371267913e+17
# modified weights
# 245.038981774
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 955557450.561
# gradient_sum_squares
# 7.74371267913e+17
# gradient_sum_squares
# 1.68746130924e+18
# modified weights
# 65.3160358597
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 276669.5177542   640134.31497086  266339.66471327 ...,  374843.20818842
#   384158.01260943  216562.14919527]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 1357220.62882
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.8420478353e+12
# modified weights
# -99999.9687965
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -859103885.812
# gradient_sum_squares
# 1.8420478353e+12
# gradient_sum_squares
# 7.38061328666e+17
# modified weights
# 245.042418189
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 932885601.386
# gradient_sum_squares
# 7.38061328666e+17
# gradient_sum_squares
# 1.60833687394e+18
# modified weights
# 65.3123043173
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 276668.57245229  640136.84024671  266332.16095246 ...,  374842.75663889
#   384158.24939408  216561.84816044]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 1348077.193
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.81731211829e+12
# modified weights
# -99999.9688018
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -838720532.849
# gradient_sum_squares
# 1.81731211829e+12
# gradient_sum_squares
# 7.03453949535e+17
# modified weights
# 245.045773072
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 910751671.217
# gradient_sum_squares
# 7.03453949535e+17
# gradient_sum_squares
# 1.53292255616e+18
# modified weights
# 65.3086613106
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 276667.64957886  640139.3056071   266324.83522813 ...,  374842.31580293
#   384158.48056067  216561.55426801]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 1339150.69671
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.7933245885e+12
# modified weights
# -99999.9688072
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -818820801.36
# gradient_sum_squares
# 1.7933245885e+12
# gradient_sum_squares
# 6.70469298065e+17
# modified weights
# 245.049048355
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 889142897.234
# gradient_sum_squares
# 6.70469298065e+17
# gradient_sum_squares
# 1.46104438977e+18
# modified weights
# 65.305104739
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 276666.74860175  640141.71247359  266317.68331612 ...,  374841.88542635
#   384158.7062425   216561.2673485 ]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 1330435.99277
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.77005993087e+12
# modified weights
# -99999.9688125
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -799393216.789
# gradient_sum_squares
# 1.77005993087e+12
# gradient_sum_squares
# 6.39031285108e+17
# modified weights
# 245.052245928
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 868046819.434
# gradient_sum_squares
# 6.39031285108e+17
# gradient_sum_squares
# 1.39253656584e+18
# modified weights
# 65.3016325517
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 276665.86900146  640144.06223404  266310.70109251 ...,  374841.46526098
#   384158.92656971  216560.98723648]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 1321928.05614
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.74749378561e+12
# modified weights
# -99999.9688178
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -780426576.858
# gradient_sum_squares
# 1.74749378561e+12
# gradient_sum_squares
# 6.0906738936e+17
# modified weights
# 245.055367634
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 847451273.418
# gradient_sum_squares
# 6.0906738936e+17
# gradient_sum_squares
# 1.32724105018e+18
# modified weights
# 65.2982427466
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 276665.01027079  640146.35624335  266303.88453122 ...,  374841.05506455
#   384159.14166933  216560.71377043]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 1313621.981
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.72560270896e+12
# modified weights
# -99999.9688231
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -761909945.039
# gradient_sum_squares
# 1.72560270896e+12
# gradient_sum_squares
# 5.80508489952e+17
# modified weights
# 245.058415274
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 827344383.438
# gradient_sum_squares
# 5.80508489952e+17
# gradient_sum_squares
# 1.26500721876e+18
# modified weights
# 65.2949333691
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 276664.17191458  640148.5958243   266297.22970171 ...,  374840.65460053
#   384159.3516654   216560.44679267]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 1305512.97791
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.70436413549e+12
# modified weights
# -99999.9688283
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -743832644.317
# gradient_sum_squares
# 1.70436413549e+12
# gradient_sum_squares
# 5.53288707115e+17
# modified weights
# 245.061390604
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 807714555.486
# gradient_sum_squares
# 5.53288707115e+17
# gradient_sum_squares
# 1.20569151026e+18
# modified weights
# 65.2917025109
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 276663.35344942  640150.78226827  266290.73276667 ...,  374840.26363801
#   384159.55667901  216560.18614925]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 1297596.37109
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.68375634226e+12
# modified weights
# -99999.9688335
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -726184250.988
# gradient_sum_squares
# 1.68375634226e+12
# gradient_sum_squares
# 5.2734525014e+17
# modified weights
# 245.064295341
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 788550470.649
# gradient_sum_squares
# 5.2734525014e+17
# gradient_sum_squares
# 1.1491570949e+18
# modified weights
# 65.288548309
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 276662.55440338  640152.916836    266284.38997985 ...,  374839.88195156
#   384159.75682837  216559.93168988]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 1289867.59569
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.6637584144e+12
# modified weights
# -99999.9688386
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -708954588.674
# gradient_sum_squares
# 1.6637584144e+12
# gradient_sum_squares
# 5.0261827256e+17
# modified weights
# 245.06713116
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 769841078.566
# gradient_sum_squares
# 5.0261827256e+17
# gradient_sum_squares
# 1.09527355881e+18
# modified weights
# 65.2854689447
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 276661.77431569  640155.00075832  266278.19768389 ...,  374839.50932108
#   384159.9522289   216559.68326784]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 1282322.19516
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.6443502122e+12
# modified weights
# -99999.9688438
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -692133722.426
# gradient_sum_squares
# 1.6443502122e+12
# gradient_sum_squares
# 4.7905073407e+17
# modified weights
# 245.069899695
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 751575591.07
# gradient_sum_squares
# 4.7905073407e+17
# gradient_sum_squares
# 1.04391660316e+18
# modified weights
# 65.2824626423
# END-------------------------------------------------------------------END
# END===================================================================END
# START===================================================================START
# Predictions:
# [ 276661.01273657  640157.03523686  266272.15230819 ...,  374839.14553171
#   384160.14299326  216559.44073989]
# 17384
# START-----------------------------------------------------------------START
# derivative
# 1274955.8187
# gradient_sum_squares
# 0
# gradient_sum_squares
# 1.62551233963e+12
# modified weights
# -99999.9688489
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# -675711953.044
# gradient_sum_squares
# 1.62551233963e+12
# gradient_sum_squares
# 4.56588268999e+17
# modified weights
# 245.072602542
# END-------------------------------------------------------------------END
# START-----------------------------------------------------------------START
# derivative
# 733743475.937
# gradient_sum_squares
# 4.56588268999e+17
# gradient_sum_squares
# 9.94967757479e+17
# modified weights
# 65.2795276684
# END-------------------------------------------------------------------END
# END===================================================================END
# [ -9.99999688e+04   2.45072603e+02   6.52795277e+01]

# %% [markdown]
# Use your newly estimated weights and the predict_output function to compute the predictions on the TEST data. Don't forget to create a numpy array for these features from the test set first!

# %%
(test_model_feature_matrix, test_output) = get_numpy_data(test_data, model_features, my_output)
model2_predictions = predict_output(test_model_feature_matrix, weights_model2)
model2_predictions
# Out:
# array([ 366651.41203656,  762662.39786164,  386312.09499712, ...,
#         682087.39928241,  585579.27865729,  216559.20396617])

# %% [markdown]
# **Quiz Question: What is the predicted price for the 1st house in the TEST data set for model 2 (round to nearest dollar)?**

# %%
model2_predictions[0]
# Out:
# 366651.41203655908

# %% [markdown]
# What is the actual price for the 1st house in the test data set?

# %%
print model2_predictions[0] - test_output[0]
#print test_output[0]
# Out:
# 56651.4120366

# %% [markdown]
# **Quiz Question: Which estimate was closer to the true price for the 1st house on the Test data set, model 1 or model 2?**

# %% [markdown]
# Now use your predictions and the output to compute the RSS for model 2 on TEST data.

# %%
errors_model2 = model2_predictions - test_output
errors_model2_squared = errors_model2 * errors_model2
rss_model2 = sum(errors_model2_squared)
rss_model2
# Out:
# 270263446465243.97

# %% [markdown]
# **Quiz Question: Which model (1 or 2) has lowest RSS on all of the TEST data? **

# %%
print rss_model1 - rss_model2
# Out:
# 5.13660112791e+12
