# %% [markdown]
# ## Load the Library

# %%
import math
import pandas as pd
import numpy as np
from scipy.stats import mode
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cross_validation import train_test_split
from sklearn.metrics import log_loss
from sklearn.preprocessing import LabelEncoder, Imputer
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def llfun(act, pred):
    """ Logloss function for 1/0 probability
    """
    return (-(~(act == pred)).astype(int) * math.log(1e-15)).sum() / len(act)

# %% [markdown]
# ## Load the Data

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %% [markdown]
# ## Data Exploration

# %%
train['source'] = 'train'
test['source'] = 'test'
data = pd.concat([train, test],ignore_index=True)
print(train.shape, test.shape, data.shape)
# Out:
# (68353, 13) (45978, 12) (114331, 13)

# %%
data.head()
# Out:
#   Customer_Location  Email_Campaign_Type           Email_ID  \
# 0                 E                    2  EMA00081000034500
# 1               NaN                    2  EMA00081000045360
# 2                 B                    3  EMA00081000066290
# 3                 E                    2  EMA00081000076560
# 4                 C                    3  EMA00081000109720
#
#    Email_Source_Type  Email_Status  Email_Type  Subject_Hotness_Score  \
# 0                  2           0.0           1                    2.2
# 1                  1           0.0           2                    2.1
# 2                  1           1.0           2                    0.1
# 3                  2           0.0           1                    3.0
# 4                  2           0.0           1                    0.0
#
#    Time_Email_sent_Category  Total_Images  Total_Links  \
# 0                         1           0.0          8.0
# 1                         2           0.0          5.0
# 2                         2           0.0          5.0
# 3                         2           0.0         16.0
# 4                         2           0.0          4.0
#
#    Total_Past_Communications  Word_Count source
# 0                       33.0         440  train
# 1                       15.0         504  train
# 2                       36.0         962  train
# 3                       25.0         610  train
# 4                       18.0         947  train

# %%
sorted1 = data.sort(['Customer_Location', 'Email_Campaign_Type'], ascending=[1, 0])
sorted1[sorted1['Customer_Location'] == 'D']['Email_Campaign_Type'].count()
# Out:
# C:\Users\ranjank\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
# 12243

# %% [markdown]
# ### Missing Data

# %%
data.apply(lambda x: sum(x.isnull()))
# Out:
# Customer_Location            19438
# Email_Campaign_Type              0
# Email_ID                         0
# Email_Source_Type                0
# Email_Status                 45978
# Email_Type                       0
# Subject_Hotness_Score            0
# Time_Email_sent_Category         0
# Total_Images                  2770
# Total_Links                   3624
# Total_Past_Communications    11515
# Word_Count                       0
# source                           0
# dtype: int64

# %%
data.describe()
# Out:
#        Email_Campaign_Type  Email_Source_Type  Email_Status     Email_Type  \
# count        114331.000000      114331.000000  68353.000000  114331.000000
# mean              2.270539           1.456928      0.230934       1.284096
# std               0.468056           0.498144      0.497032       0.450985
# min               1.000000           1.000000      0.000000       1.000000
# 25%               2.000000           1.000000      0.000000       1.000000
# 50%               2.000000           1.000000      0.000000       1.000000
# 75%               3.000000           2.000000      0.000000       2.000000
# max               3.000000           2.000000      2.000000       2.000000
#
#        Subject_Hotness_Score  Time_Email_sent_Category   Total_Images  \
# count          114331.000000             114331.000000  111561.000000
# mean                1.095876                  1.997945       3.535178
# std                 0.996247                  0.631809       5.592399
# min                 0.000000                  1.000000       0.000000
# 25%                 0.200000                  2.000000       0.000000
# 50%                 0.800000                  2.000000       0.000000
# 75%                 1.800000                  2.000000       5.000000
# max                 5.000000                  3.000000      47.000000
#
#         Total_Links  Total_Past_Communications     Word_Count
# count  110707.00000              102816.000000  114331.000000
# mean       10.41291                  28.892225     701.350885
# std         6.39044                  12.528849     271.875965
# min         1.00000                   0.000000      40.000000
# 25%         6.00000                  20.000000     521.000000
# 50%         9.00000                  28.000000     694.000000
# 75%        14.00000                  38.000000     880.000000
# max        49.00000                  67.000000    1316.000000

# %%
data.apply(lambda x: len(x.unique()))
# Out:
# Customer_Location                 9
# Email_Campaign_Type               3
# Email_ID                     114331
# Email_Source_Type                 2
# Email_Status                      4
# Email_Type                        2
# Subject_Hotness_Score            51
# Time_Email_sent_Category          3
# Total_Images                     47
# Total_Links                      38
# Total_Past_Communications        65
# Word_Count                      151
# source                            2
# dtype: int64

# %%
#Filter categorical variables
categorical_columns = [x for x in data.dtypes.index if data.dtypes[x]=='object']

#Exclude ID cols and source:
categorical_columns = [x for x in categorical_columns if x not in ['Email_ID','source']]

#Print frequency of categories
for col in categorical_columns:
    print('\nFrequency of Categories for varible %s'%col)
    print(data[col].value_counts())
# Out:
# Frequency of Categories for varible Customer_Location
# G    38818
# E    17052
# D    12243
# C     9725
# F     7368
# B     7236
# A     2416
# H       35
# Name: Customer_Location, dtype: int64

# %%
categorical_columns
# Out:
# ['Customer_Location']

# %% [markdown]
# ## Data Cleaning

# %%
#[x for x in data.values if x not in data[data['Customer_Location'].isnull()]]
#data[data['Customer_Location'].isnull()]
features = ['Email_Campaign_Type', 'Email_Source_Type', 'Email_Type',
       'Subject_Hotness_Score', 'Time_Email_sent_Category', 'Word_Count']
target = ['Customer_Location']

le = LabelEncoder()
data1 = data[features + target].loc[data['Customer_Location'].isnull() == False]
X = data1[features]
y = data1[target]
y = le.fit_transform(y)
print(len(X), y)
# Out:
# 94893 [4 1 4 ..., 6 4 4]
# C:\Users\ranjank\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:125: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=1)

# %%
print(len(X_train),  len(y_train), len(X_test), len(y_test))
print(y_train, y_test)
# Out:
# 75914 75914 18979 18979
# [6 6 3 ..., 5 6 0] [6 5 4 ..., 6 6 1]

# %%
# Fit
logloss = []
for i in range(1, 50, 1):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    
    # Predict on test set
    outcome = knn.predict(X_test)
    
    # Logloss
    logloss.append(llfun(y_test, outcome))

# %%
plt.plot(logloss)
plt.plot()
#plt.savefig('n_neighbors_vs_logloss.png')
# Out:
# []

# %%
data2 = data[features].loc[data['Customer_Location'].isnull() == True]

# %%
knn = KNeighborsClassifier(n_neighbors=47)
knn.fit(X, y)
outcomes = knn.predict(data2)

# %%
outcomes = le.inverse_transform(outcomes)

# %%
#outcomes = pd.DataFrame(outcomes)
#outcomes.apply(lambda x: sum(x.isnull()))

# %%
data2.loc[:,'Customer_Location'] = pd.Series(outcomes, index=data2.index)

# %%
data2.apply(lambda x: sum(x.isnull()))
# Out:
# Email_Campaign_Type         0
# Email_Source_Type           0
# Email_Type                  0
# Subject_Hotness_Score       0
# Time_Email_sent_Category    0
# Word_Count                  0
# Customer_Location           0
# dtype: int64

# %%
data3 = data1.append(data2)

# %%
data.head()
# Out:
#   Customer_Location  Email_Campaign_Type           Email_ID  \
# 0                 E                    2  EMA00081000034500
# 1               NaN                    2  EMA00081000045360
# 2                 B                    3  EMA00081000066290
# 3                 E                    2  EMA00081000076560
# 4                 C                    3  EMA00081000109720
#
#    Email_Source_Type  Email_Status  Email_Type  Subject_Hotness_Score  \
# 0                  2           0.0           1                    2.2
# 1                  1           0.0           2                    2.1
# 2                  1           1.0           2                    0.1
# 3                  2           0.0           1                    3.0
# 4                  2           0.0           1                    0.0
#
#    Time_Email_sent_Category  Total_Images  Total_Links  \
# 0                         1           0.0          8.0
# 1                         2           0.0          5.0
# 2                         2           0.0          5.0
# 3                         2           0.0         16.0
# 4                         2           0.0          4.0
#
#    Total_Past_Communications  Word_Count source
# 0                       33.0         440  train
# 1                       15.0         504  train
# 2                       36.0         962  train
# 3                       25.0         610  train
# 4                       18.0         947  train

# %%
data.columns
# Out:
# Index(['Customer_Location', 'Email_Campaign_Type', 'Email_ID',
#        'Email_Source_Type', 'Email_Status', 'Email_Type',
#        'Subject_Hotness_Score', 'Time_Email_sent_Category', 'Total_Images',
#        'Total_Links', 'Total_Past_Communications', 'Word_Count', 'source'],
#       dtype='object')

# %%
data3.columns
# Out:
# Index(['Email_Campaign_Type', 'Email_Source_Type', 'Email_Type',
#        'Subject_Hotness_Score', 'Time_Email_sent_Category', 'Word_Count',
#        'Customer_Location'],
#       dtype='object')

# %%
remaining_columns = [x for x in data.columns if x not in data3.columns]
remaining_columns
# Out:
# ['Email_ID',
#  'Email_Status',
#  'Total_Images',
#  'Total_Links',
#  'Total_Past_Communications',
#  'source']

# %%
data3[remaining_columns] = data[remaining_columns]
# Out:
#         Email_Campaign_Type  Email_Source_Type  Email_Type  \
# 0                         2                  2           1
# 2                         3                  1           2
# 3                         2                  2           1
# 4                         3                  2           1
# 5                         2                  1           1
# 6                         2                  1           1
# 7                         2                  2           1
# 8                         2                  1           1
# 9                         2                  1           2
# 10                        3                  1           2
# 11                        2                  1           1
# 12                        3                  1           2
# 13                        2                  1           2
# 14                        2                  1           1
# 16                        2                  2           1
# 17                        2                  1           1
# 18                        2                  1           2
# 19                        2                  2           1
# 20                        3                  1           1
# 22                        3                  2           1
# 23                        2                  2           1
# 24                        2                  2           1
# 25                        2                  1           2
# 26                        3                  2           1
# 27                        2                  1           2
# 29                        2                  1           1
# 30                        2                  2           1
# 31                        3                  2           2
# 32                        2                  1           1
# 33                        2                  2           1
# ...                     ...                ...         ...
# 114128                    2                  1           2
# 114149                    2                  2           1
# 114155                    2                  1           1
# 114157                    2                  1           1
# 114165                    2                  2           1
# 114169                    3                  1           2
# 114192                    2                  2           1
# 114195                    2                  2           1
# 114196                    2                  2           1
# 114197                    3                  1           1
# 114219                    2                  2           1
# 114224                    2                  2           1
# 114233                    2                  1           2
# 114244                    3                  2           1
# 114245                    2                  2           1
# 114254                    3                  2           2
# 114261                    3                  1           2
# 114263                    3                  2           2
# 114265                    2                  1           2
# 114278                    2                  2           1
# 114286                    2                  2           1
# 114288                    3                  2           1
# 114294                    2                  2           1
# 114295                    2                  1           1
# 114308                    2                  2           1
# 114311                    2                  1           1
# 114314                    2                  2           1
# 114315                    2                  2           1
# 114319                    2                  2           1
# 114329                    2                  1           2
#
#         Subject_Hotness_Score  Time_Email_sent_Category  Word_Count  \
# 0                         2.2                         1         440
# 2                         0.1                         2         962
# 3                         3.0                         2         610
# 4                         0.0                         2         947
# 5                         1.5                         2         416
# 6                         3.2                         3         116
# 7                         0.7                         2        1241
# 8                         2.0                         3         655
# 9                         0.5                         3         655
# 10                        0.2                         3         744
# 11                        1.0                         2         931
# 12                        0.1                         2         550
# 13                        4.0                         2         565
# 14                        3.0                         3         700
# 16                        2.1                         3         610
# 17                        1.1                         1        1061
# 18                        0.7                         2         623
# 19                        1.6                         1         560
# 20                        0.3                         2        1082
# 22                        0.2                         1         733
# 23                        2.3                         2        1122
# 24                        2.3                         2         649
# 25                        1.4                         2         778
# 26                        0.1                         3         855
# 27                        1.7                         2         704
# 29                        1.2                         2         988
# 30                        0.8                         2         389
# 31                        0.0                         2         389
# 32                        1.4                         1         636
# 33                        0.6                         3         812
# ...                       ...                       ...         ...
# 114128                    0.4                         2         251
# 114149                    3.2                         2         389
# 114155                    0.5                         2         593
# 114157                    1.4                         3         623
# 114165                    2.9                         1         593
# 114169                    0.0                         1         741
# 114192                    1.7                         2         796
# 114195                    0.7                         2         424
# 114196                    2.1                         3          67
# 114197                    0.0                         2         972
# 114219                    2.0                         1        1157
# 114224                    1.1                         3         623
# 114233                    1.4                         3         694
# 114244                    0.0                         2         947
# 114245                    2.7                         3         282
# 114254                    0.2                         2         484
# 114261                    0.3                         3         744
# 114263                    0.1                         1         311
# 114265                    1.3                         2         339
# 114278                    2.5                         2         988
# 114286                    1.9                         2         662
# 114288                    0.2                         3         778
# 114294                    2.3                         2         741
# 114295                    1.9                         2         988
# 114308                    1.7                         3         416
# 114311                    0.6                         1         661
# 114314                    1.7                         1         873
# 114315                    0.5                         2         673
# 114319                    0.9                         2         440
# 114329                    1.8                         3         673
#
#        Customer_Location           Email_ID  Email_Status  Total_Images  \
# 0                      E  EMA00081000034500           0.0           0.0
# 2                      B  EMA00081000066290           1.0           0.0
# 3                      E  EMA00081000076560           0.0           0.0
# 4                      C  EMA00081000109720           0.0           0.0
# 5                      G  EMA00081000131660           0.0           0.0
# 6                      E  EMA00081000160500           0.0           0.0
# 7                      G  EMA00081000269630           0.0           2.0
# 8                      G  EMA00081000287790           0.0           4.0
# 9                      G  EMA00081000367310           0.0           0.0
# 10                     G  EMA00081000428660           0.0           0.0
# 11                     D  EMA00081000583620           0.0          16.0
# 12                     C  EMA00081000591290           0.0           0.0
# 13                     E  EMA00081000667000           0.0           0.0
# 14                     G  EMA00081000781390           0.0          13.0
# 16                     B  EMA00081001086910           0.0           4.0
# 17                     G  EMA00081001137220           0.0          15.0
# 18                     E  EMA00081001215220           0.0           0.0
# 19                     F  EMA00081001358710           0.0           0.0
# 20                     F  EMA00081001535890           0.0           4.0
# 22                     G  EMA00081001736520           1.0           5.0
# 23                     G  EMA00081001769720           0.0           0.0
# 24                     E  EMA00081001994960           0.0          28.0
# 25                     G  EMA00081002046220           0.0           0.0
# 26                     G  EMA00081002124310           0.0           4.0
# 27                     G  EMA00081002245070           0.0           0.0
# 29                     G  EMA00081002403600           0.0           0.0
# 30                     D  EMA00081002406910           1.0           3.0
# 31                     E  EMA00081002494510           1.0           0.0
# 32                     B  EMA00081002583980           0.0           8.0
# 33                     G  EMA00081002630210           0.0           8.0
# ...                  ...                ...           ...           ...
# 114128                 G  EMA00089710912400           NaN           0.0
# 114149                 G  EMA00089730877900           NaN           0.0
# 114155                 G  EMA00089733438600           NaN           0.0
# 114157                 G  EMA00089735436700           NaN           0.0
# 114165                 G  EMA00089740451900           NaN           0.0
# 114169                 G  EMA00089746436600           NaN          12.0
# 114192                 G  EMA00089774896500           NaN           7.0
# 114195                 G  EMA00089787493800           NaN           6.0
# 114196                 G  EMA00089788657800           NaN           0.0
# 114197                 G  EMA00089790706900           NaN           1.0
# 114219                 G  EMA00089828797300           NaN           6.0
# 114224                 G  EMA00089836802900           NaN           8.0
# 114233                 G  EMA00089849357500           NaN           0.0
# 114244                 G  EMA00089870409700           NaN           2.0
# 114245                 G  EMA00089872285500           NaN          11.0
# 114254                 G  EMA00089883832500           NaN          11.0
# 114261                 G  EMA00089892273500           NaN           1.0
# 114263                 G  EMA00089896718200           NaN           1.0
# 114265                 G  EMA00089899354900           NaN           0.0
# 114278                 G  EMA00089915392400           NaN           4.0
# 114286                 G  EMA00089928180500           NaN           0.0
# 114288                 G  EMA00089931258200           NaN           5.0
# 114294                 G  EMA00089938200600           NaN           0.0
# 114295                 G  EMA00089940390900           NaN           6.0
# 114308                 G  EMA00089958214800           NaN           0.0
# 114311                 G  EMA00089966761100           NaN           0.0
# 114314                 G  EMA00089969299700           NaN          11.0
# 114315                 G  EMA00089969799200           NaN           0.0
# 114319                 G  EMA00089973990500           NaN           4.0
# 114329                 G  EMA00089997508900           NaN           0.0
#
#         Total_Links  Total_Past_Communications source
# 0               8.0                       33.0  train
# 2               5.0                       36.0  train
# 3              16.0                       25.0  train
# 4               4.0                       18.0  train
# 5              11.0                        NaN  train
# 6               4.0                       34.0  train
# 7               6.0                       21.0  train
# 8              11.0                        NaN  train
# 9              11.0                       40.0  train
# 10              6.0                       27.0  train
# 11             21.0                       24.0  train
# 12              6.0                       42.0  train
# 13              NaN                       11.0  train
# 14              NaN                       15.0  train
# 16             21.0                       34.0  train
# 17             21.0                        NaN  train
# 18             16.0                       33.0  train
# 19              6.0                       37.0  train
# 20             16.0                       35.0  train
# 22              6.0                       51.0  train
# 23              4.0                        9.0  train
# 24             31.0                       18.0  train
# 25              3.0                       25.0  train
# 26             21.0                       39.0  train
# 27             11.0                        NaN  train
# 29              9.0                        NaN  train
# 30              6.0                       31.0  train
# 31              4.0                       50.0  train
# 32             16.0                       30.0  train
# 33             26.0                       39.0  train
# ...             ...                        ...    ...
# 114128          9.0                       45.0   test
# 114149          NaN                       21.0   test
# 114155          9.0                       38.0   test
# 114157          9.0                       26.0   test
# 114165         11.0                       11.0   test
# 114169         16.0                       31.0   test
# 114192         21.0                       25.0   test
# 114195         14.0                       22.0   test
# 114196          6.0                       30.0   test
# 114197          4.0                       16.0   test
# 114219         11.0                       16.0   test
# 114224          9.0                       23.0   test
# 114233          6.0                       34.0   test
# 114244          6.0                       30.0   test
# 114245         14.0                       29.0   test
# 114254         14.0                       31.0   test
# 114261         11.0                       29.0   test
# 114263          5.0                       25.0   test
# 114265          4.0                       37.0   test
# 114278          5.0                       15.0   test
# 114286          6.0                       10.0   test
# 114288         11.0                       21.0   test
# 114294          6.0                       18.0   test
# 114295         16.0                       23.0   test
# 114308         11.0                       35.0   test
# 114311          6.0                       30.0   test
# 114314         26.0                       33.0   test
# 114315         12.0                       32.0   test
# 114319          6.0                       43.0   test
# 114329          9.0                       22.0   test
#
# [114331 rows x 13 columns]

# %%
data3.head()
# Out:
#    Email_Campaign_Type  Email_Source_Type  Email_Type  Subject_Hotness_Score  \
# 0                    2                  2           1                    2.2
# 2                    3                  1           2                    0.1
# 3                    2                  2           1                    3.0
# 4                    3                  2           1                    0.0
# 5                    2                  1           1                    1.5
#
#    Time_Email_sent_Category  Word_Count Customer_Location           Email_ID  \
# 0                         1         440                 E  EMA00081000034500
# 2                         2         962                 B  EMA00081000066290
# 3                         2         610                 E  EMA00081000076560
# 4                         2         947                 C  EMA00081000109720
# 5                         2         416                 G  EMA00081000131660
#
#    Email_Status  Total_Images  Total_Links  Total_Past_Communications source
# 0           0.0           0.0          8.0                       33.0  train
# 2           1.0           0.0          5.0                       36.0  train
# 3           0.0           0.0         16.0                       25.0  train
# 4           0.0           0.0          4.0                       18.0  train
# 5           0.0           0.0         11.0                        NaN  train

# %%
data3.apply(lambda x: sum(x.isnull()))
# Out:
# Email_Campaign_Type              0
# Email_Source_Type                0
# Email_Type                       0
# Subject_Hotness_Score            0
# Time_Email_sent_Category         0
# Word_Count                       0
# Customer_Location                0
# Email_ID                         0
# Email_Status                 45978
# Total_Images                  2770
# Total_Links                   3624
# Total_Past_Communications    11515
# source                           0
# dtype: int64

# %%
features4 = ['Email_Campaign_Type', 'Email_Source_Type', 'Email_Type',
       'Subject_Hotness_Score', 'Time_Email_sent_Category', 'Total_Images',
       'Total_Links', 'Total_Past_Communications', 'Word_Count']
data4 = data3[features4]
imputer = Imputer(missing_values='NaN', strategy='mean', axis=0)
imputed_data = imputer.fit_transform(data4)
data5 = pd.DataFrame(imputed_data, index=data4.index, columns=data4.columns)

# %%
data3.columns
# Out:
# Index(['Email_Campaign_Type', 'Email_Source_Type', 'Email_Type',
#        'Subject_Hotness_Score', 'Time_Email_sent_Category', 'Word_Count',
#        'Customer_Location', 'Email_ID', 'Email_Status', 'Total_Images',
#        'Total_Links', 'Total_Past_Communications', 'source'],
#       dtype='object')

# %%
data5[['source', 'Email_ID', 'Email_Status', 'Customer_Location']] = data3[['source', 'Email_ID', 'Email_Status', 'Customer_Location']]

# %%
data5.apply(lambda x: sum(x.isnull()))
# Out:
# Email_Campaign_Type              0
# Email_Source_Type                0
# Email_Type                       0
# Subject_Hotness_Score            0
# Time_Email_sent_Category         0
# Total_Images                     0
# Total_Links                      0
# Total_Past_Communications        0
# Word_Count                       0
# source                           0
# Email_ID                         0
# Email_Status                 45978
# Customer_Location                0
# dtype: int64

# %%
data5.head()
# Out:
#    Email_Campaign_Type  Email_Source_Type  Email_Type  Subject_Hotness_Score  \
# 0                  2.0                2.0         1.0                    2.2
# 2                  3.0                1.0         2.0                    0.1
# 3                  2.0                2.0         1.0                    3.0
# 4                  3.0                2.0         1.0                    0.0
# 5                  2.0                1.0         1.0                    1.5
#
#    Time_Email_sent_Category  Total_Images  Total_Links  \
# 0                       1.0           0.0          8.0
# 2                       2.0           0.0          5.0
# 3                       2.0           0.0         16.0
# 4                       2.0           0.0          4.0
# 5                       2.0           0.0         11.0
#
#    Total_Past_Communications  Word_Count source           Email_ID  \
# 0                  33.000000       440.0  train  EMA00081000034500
# 2                  36.000000       962.0  train  EMA00081000066290
# 3                  25.000000       610.0  train  EMA00081000076560
# 4                  18.000000       947.0  train  EMA00081000109720
# 5                  28.892225       416.0  train  EMA00081000131660
#
#    Email_Status Customer_Location
# 0           0.0                 E
# 2           1.0                 B
# 3           0.0                 E
# 4           0.0                 C
# 5           0.0                 G

# %%
#One Hot Coding:
data5 = pd.get_dummies(data5, columns=['Email_Campaign_Type','Email_Source_Type','Email_Type','Time_Email_sent_Category',
                              'Customer_Location'])

# %%
data5.dtypes
# Out:
# Subject_Hotness_Score           float64
# Total_Images                    float64
# Total_Links                     float64
# Total_Past_Communications       float64
# Word_Count                      float64
# source                           object
# Email_ID                         object
# Email_Status                    float64
# Email_Campaign_Type_1.0         float64
# Email_Campaign_Type_2.0         float64
# Email_Campaign_Type_3.0         float64
# Email_Source_Type_1.0           float64
# Email_Source_Type_2.0           float64
# Email_Type_1.0                  float64
# Email_Type_2.0                  float64
# Time_Email_sent_Category_1.0    float64
# Time_Email_sent_Category_2.0    float64
# Time_Email_sent_Category_3.0    float64
# Customer_Location_A             float64
# Customer_Location_B             float64
# Customer_Location_C             float64
# Customer_Location_D             float64
# Customer_Location_E             float64
# Customer_Location_F             float64
# Customer_Location_G             float64
# Customer_Location_H             float64
# dtype: object

# %%
#Divide into test and train:
train = data5.loc[data['source']=="train"]
test = data5.loc[data['source']=="test"]

# %%
test.apply(lambda x: sum(x.isnull()))
# Out:
# Subject_Hotness_Score               0
# Total_Images                        0
# Total_Links                         0
# Total_Past_Communications           0
# Word_Count                          0
# source                              0
# Email_ID                            0
# Email_Status                    45978
# Email_Campaign_Type_1.0             0
# Email_Campaign_Type_2.0             0
# Email_Campaign_Type_3.0             0
# Email_Source_Type_1.0               0
# Email_Source_Type_2.0               0
# Email_Type_1.0                      0
# Email_Type_2.0                      0
# Time_Email_sent_Category_1.0        0
# Time_Email_sent_Category_2.0        0
# Time_Email_sent_Category_3.0        0
# Customer_Location_A                 0
# Customer_Location_B                 0
# Customer_Location_C                 0
# Customer_Location_D                 0
# Customer_Location_E                 0
# Customer_Location_F                 0
# Customer_Location_G                 0
# Customer_Location_H                 0
# dtype: int64

# %%
#Drop unnecessary columns:
test.drop(['Email_Status','source'],axis=1,inplace=True)
train.drop(['source'],axis=1,inplace=True)
# Out:
# C:\Users\ranjank\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\ranjank\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
#Export files as modified versions:
train.to_csv("train_modified.csv",index=False)
test.to_csv("test_modified.csv",index=False)
